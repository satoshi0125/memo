# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ave_temp = 36.5
time = np.arange(0,25,3)
temp = np.array([36.7,36.9,37.1,37.2,37.2,None,38.1,37.7,None])

# %%
len(time)
# Out:
# 9

# %%
len(temp)
# Out:
# 9

# %%
list([36.6])*5
# Out:
# [36.6, 36.6, 36.6, 36.6, 36.6]

# %%
plt.plot(time,temp,label='measured')
plt.scatter(time,temp)
plt.xlabel("elapsed time [hour]",fontsize=15)
plt.ylabel("body temperature [℃]",fontsize=15)
plt.xlim(0,24)
plt.ylim(36,39)
plt.plot(time,list([36.6])*len(time),color='green',label='normal')
plt.hlines(np.arange(36, 50, 0.5),0,50,linestyle='dashed',color='silver')
plt.legend()
plt.show()

# %% [markdown]
# ## 所感
# -
