# %% [markdown]
# # 機械学習メモ
# ### 背景
# 「機械学習を散々勉強してきたんですが、数式の中身を理解せずに使うのってどうなの？」
#
# という疑問から**数式から理解する機械学習**をやってみようかなと思います。

# %% [markdown]
# >数式を書くときの参考文献<br>
# ・[Qiitaの数式チートシート](https://qiita.com/PlanetMeron/items/63ac58898541cbe81ada)<br>
# ・[Jupyter Notebook で数式を美しく書く](https://qiita.com/namoshika/items/63db972bfd1030f8264a)<br>
# ・ \：バックスラッシュは 'option' + '¥'で書ける

# %% [markdown]
# ## 回帰分析(regression analysis)
# $$
# 入力 x \in R^M と出力 y \in R との組で表現されるデータが N 個あるとする
# $$
# $$
# Z \equiv ( (x_1,y_1),(x_2,y_2), ・・・ , (x_N,y_N))
# $$
#
# $$
# 未知入力 x_uに対して、出力y_uを予測する \Longrightarrow 学習
# $$
#
# $$
# 出力が連続値 y \in R である場合：関数関係推定問題、回帰問題になる。
# $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# coding:utf-8
import numpy as np
import matplotlib.pyplot as plt # グラフ描画ライブラリ

# %%
x = np.array([-0.4, -0.5667, 0.2333, 0.0, 0.0667, -0.3333, 0.3333, 0.5, -0.6, -0.2333] )
y = np.array( [ [-0.3333], [-0.2333], [0.2667], [0.2333], [0.3],[-0.0667], [0.4667], [0.4333], [-0.3], [0.0667]])
Phi = np.array( [x**i for i in range(2)] )
theta = np.dot( np.dot( np.linalg.inv( np.dot( Phi, Phi.T ) ), Phi ), y ) 
print('theta =', theta )
plt.scatter( x , y, color='blue' ) # 散布図の描画
xx = np.arange( x.min(), x.max(), ( x.max() - x.min() ) / 100.0 ) 
P = np.vstack( [xx**0, xx**1] )
plt.plot( xx, np.dot( P.T, theta ), color='red', linewidth='1.0' ) 
plt.show() # グラフの表示
# Out:
# theta = [[0.15796298]
#  [0.7462298 ]]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
